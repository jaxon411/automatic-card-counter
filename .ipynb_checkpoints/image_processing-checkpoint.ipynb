# %%
import matplotlib
from PIL import Image
import os
import random

# %%
img = Image.open(r'../automatic-card-counter/imgs/2021-01-06-204950_1.jpg')

# %%
width,height = img.size
left = 0
top = height/2
right = width
bottom = height

# %%
left = 0
top1 = 0
right = width
bottom1 = height/2
img.crop((left,top1,right,bottom1))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x288 at 0x7F5AC0746690>

# %%
img_c
# Out:
# <PIL.Image.Image image mode=RGB size=1024x288 at 0x7F5ACC368DD0>

# %%
for path in os.listdir('../automatic-card-counter/imgs/'):
    img = Image.open('../automatic-card-counter/imgs/'+path)
    width,height = img.size
    img.crop((0,0,width,height/2)).save('../automatic-card-counter/imgs_cropped/'+path[:-4]+'_1'+'.jpg','JPEG')
    img.crop((0,height/2,width,height)).save('../automatic-card-counter/imgs_cropped/'+path[:-4]+'_2'+'.jpg','JPEG')

# %%
img_c.save('../automatic-card-counter/imgs_cropped/test.jpg')

# %%
dirs = os.listdir('../automatic-card-counter/imgs_cropped/')

# %%
len(dirs)
# Out:
# 819

# %%
dirs[0]
# Out:
# '2021-01-06-204950_502_2.jpg'

# %%
random.shuffle(dirs)
dirs[0]
# Out:
# '2021-01-06-204950_353_2.jpg'

# %%
dirs = os.listdir('../automatic-card-counter/imgs_cropped/')
random.shuffle(dirs)
for i,path in enumerate(dirs):
    if i < 653:
        os.rename('../automatic-card-counter/imgs_cropped/'+path,'../automatic-card-counter/train/'+path)
    else:
        os.rename('../automatic-card-counter/imgs_cropped/'+path,'../automatic-card-counter/val/'+path)
